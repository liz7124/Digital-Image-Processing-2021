# %% [markdown]
# ## Chapter 1.4.4 Smoothing Images

# %% [markdown]
# ### 2D Convolution ( Image Filtering )

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('R.png')

# %%
s = 1
kernel = np.ones((s,s),np.float32)/(s*s)
dst = cv2.filter2D(img,-1,kernel)
plt.figure(figsize=(10,12))
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
s = 3
kernel = np.ones((s,s),np.float32)/(s*s)
dst = cv2.filter2D(img,-1,kernel)
plt.figure(figsize=(10,12))
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
s = 5
kernel = np.ones((s,s),np.float32)/(s*s)
dst = cv2.filter2D(img,-1,kernel)
plt.figure(figsize=(10,12))
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
s = 9
kernel = np.ones((s,s),np.float32)/(s*s)
dst = cv2.filter2D(img,-1,kernel)
plt.figure(figsize=(10,12))
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
print(kernel)
# Out:
# [[0.01234568 0.01234568 0.01234568 0.01234568 0.01234568 0.01234568
#   0.01234568 0.01234568 0.01234568]
#  [0.01234568 0.01234568 0.01234568 0.01234568 0.01234568 0.01234568
#   0.01234568 0.01234568 0.01234568]
#  [0.01234568 0.01234568 0.01234568 0.01234568 0.01234568 0.01234568
#   0.01234568 0.01234568 0.01234568]
#  [0.01234568 0.01234568 0.01234568 0.01234568 0.01234568 0.01234568
#   0.01234568 0.01234568 0.01234568]
#  [0.01234568 0.01234568 0.01234568 0.01234568 0.01234568 0.01234568
#   0.01234568 0.01234568 0.01234568]
#  [0.01234568 0.01234568 0.01234568 0.01234568 0.01234568 0.01234568
#   0.01234568 0.01234568 0.01234568]
#  [0.01234568 0.01234568 0.01234568 0.01234568 0.01234568 0.01234568
#   0.01234568 0.01234568 0.01234568]
#  [0.01234568 0.01234568 0.01234568 0.01234568 0.01234568 0.01234568
#   0.01234568 0.01234568 0.01234568]
#  [0.01234568 0.01234568 0.01234568 0.01234568 0.01234568 0.01234568
#   0.01234568 0.01234568 0.01234568]]

# %% [markdown]
# ### Image Blurring (Image Smoothing)

# %% [markdown]
# ### 1. Averaging

# %%
blur = cv2.blur(img,(5,5))
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ### 2. Gaussian Filtering

# %%
blur = cv2.GaussianBlur(img,(5,5),0)
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ### 3. Median Filtering

# %%
median = cv2.medianBlur(img,5)
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(median),plt.title('Median')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
img = cv2.imread('salt-and-pepper1.png')
#img = cv2.imread('salt-and-pepper2.jpg')

# %%
s=5
blur = cv2.GaussianBlur(img,(s,s),0)
median = cv2.medianBlur(img,s)
plt.figure(figsize=(10,12))
plt.subplot(121),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(median),plt.title('Median')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ### 4. Bilateral Filtering

# %%
blur = cv2.bilateralFilter(img,9,75,75)
plt.figure(figsize=(10,12))
plt.subplot(121),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(median),plt.title('Median')
plt.xticks([]), plt.yticks([])
plt.show()
