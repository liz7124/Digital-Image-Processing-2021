# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('dsu4.jpg')
img.shape
# Out:
# (768, 1024, 3)

# %%
rows,cols,ch = img.shape
pts1 = np.float32([[240, 268], [569, 232], [566, 493],[238, 458]])
pts2 = np.float32([[0,0],[800,0],[800,400],[0,400]])
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(800,400))
plt.figure(figsize=(16,12))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %%
img = cv2.imread('dsu7.jpg')
img.shape
# Out:
# (768, 1024, 3)

# %%
rows,cols,ch = img.shape
pts1 = np.float32([[0, 241], [1023, 78], [1023, 645],[0, 558]])
pts2 = np.float32([[0,0],[800,0],[800,400],[0,400]])
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(800,400))
plt.figure(figsize=(16,12))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()
